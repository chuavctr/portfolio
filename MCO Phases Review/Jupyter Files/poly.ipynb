# %% [markdown]
# ## PRE-MCO

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#importing the dataset
dataset = pd.read_csv(r'C19 Pre-MCO.csv')

dataset = dataset[['date','day','new_cases_malaysia']]

# %%
X = dataset.iloc[:, 1].values.reshape(-1,1)
y = dataset.iloc[:, 2].values.reshape(-1,1)

#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)

#Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('New Cases during PRE-MCO (Polynomial Regression)')
    plt.xlabel('Day Count')
    plt.ylabel('No. of new cases')
    plt.show
    return
viz_polymonial()

# %% [markdown]
# ## MCO

# %%
#importing the dataset
dataset = pd.read_csv(r'C:\Users\user\Desktop\Data Sci Assignment Final\C19 MCO.csv')

dataset = dataset[['date','day','new_cases_malaysia']]

# %%
X = dataset.iloc[:, 1].values.reshape(-1,1)
y = dataset.iloc[:, 2].values.reshape(-1,1)

#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)

#Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('New Cases during MCO (Polynomial Regression)')
    plt.xlabel('Day Count')
    plt.ylabel('No. of new cases')
    plt.show
    return
viz_polymonial()

# %% [markdown]
# ## CMCO

# %%
#importing the dataset
dataset = pd.read_csv(r'C:\Users\user\Desktop\Data Sci Assignment Final\C19 CMCO.csv')

dataset = dataset[['date','day','new_cases_malaysia']]

# %%
X = dataset.iloc[:, 1].values.reshape(-1,1)
y = dataset.iloc[:, 2].values.reshape(-1,1)

#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)

#Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('New Cases during CMCO (Polynomial Regression)')
    plt.xlabel('Day Count')
    plt.ylabel('No. of new cases')
    plt.show
    return
viz_polymonial()

# %% [markdown]
# ## RMCO

# %%
#importing the dataset
dataset = pd.read_csv(r'C:\Users\user\Desktop\Data Sci Assignment Final\C19 RMCO.csv')

dataset = dataset[['date','id','new_cases_malaysia']]

# %%
X = dataset.iloc[:, 1].values.reshape(-1,1)
y = dataset.iloc[:, 2].values.reshape(-1,1)

#Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#Fitting Linear Regression to the dataset
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()
lin_reg.fit(X, y)

#Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=4)
X_poly = poly_reg.fit_transform(X)
pol_reg = LinearRegression()
pol_reg.fit(X_poly, y)

# Visualizing the Polymonial Regression results
def viz_polymonial():
    plt.scatter(X, y, color='red')
    plt.plot(X, pol_reg.predict(poly_reg.fit_transform(X)), color='blue')
    plt.title('New Cases during RMCO (Polynomial Regression)')
    plt.xlabel('Day Count')
    plt.ylabel('No. of new cases')
    plt.show
    return
viz_polymonial()
